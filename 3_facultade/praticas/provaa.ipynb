# %%
Faça um Programa que peça as 5 notas, calcule e mostre a media

# %%
soma = 0
for a in range(1,6):
  nota = int (input(f"Digite nota {a}: "))
  soma += nota

 


print(f"a media e {soma/5}")
# Out:
# Digite nota 1: 8
# Digite nota 2: 8
# Digite nota 3: 8
# Digite nota 4: 8
# Digite nota 5: 8
# a media e 8.0

# %% [markdown]
# Faça um algoritmo que solicite os dados de acesso Login e Senha. O algoritmo deve verificar se os dados de acesso digitados estão de acordo com o que esta armazenado. escreva mensagem de sucesso caso o login de certo ou uma mensagem sinalizando que os dado estão errados.

# %%
login = input("digite um usuario : ")
senha = input("digite uma senha : ")

while((login != "fulanodetal@gamil.com") and (senha != "123@456")):
  login = input("digite um usuario Valido: ")
  senha = input("digite uma senha Valido: ")

  
print("Login efectuado com  sucesso")
# Out:
# digite um usuario :
# digite uma senha : 5
# digite um usuario Valido: 5
# digite uma senha Valido: 2
# digite um usuario Valido: fulanodetal@gamil.com
# digite uma senha Valido: 123@456
# Login efectuado com  sucesso

# %% [markdown]
# escreva um algoritmo que receba numeros do usuario enquanto eles forem positivos. guando o usuario imprimior quantos numeros foran digitados

# %%
s = 0
digite = int (input(" digite um numero: "))
while(digite > 0):
    digite = int (input(" digite um numero: "))
    s += 1 

print(s)
# Out:
#  digite um numero: 1
#  digite um numero: 2
#  digite um numero: 5
#  digite um numero: -2
# 3

# %% [markdown]
# escreva um algoritmo que leia 50 numeros e escreva a media dos numeros pares e a soma dos numeros inpares

# %%
spa = 0
sin = 0
s = 0
for a in range(1,50+1):
  n = int(input('Digite um numero: '))

  if (n %2 == 0):
    spa += n
    s += 1

  if( n % 2 != 0):
    sin += n

print(f"a media dos numero par sao {spa/s:.0f}")
print(f"a soma dos numero impar sao {sin}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-110-4d49f023dbea> in <module>
#       3 s = 0
#       4 for a in range(1,50+1):
# ----> 5   n = int(input('Digite um numero: '))
#       6
#       7   if (n %2 == 0):
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
# ...
